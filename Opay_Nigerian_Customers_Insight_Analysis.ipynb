# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("C:/Users/GABRIEL JOHNSON/Documents/Africas DeepTech Challage Prjoect/Dataset/nigerian_users.csv")

# %%
dataset.head(12)
# Out:
#                                  user_id  first_name last_name  phone_number  \
# 0   f1c19208-f1ee-44a1-a295-8deed0332f81   Happiness   Okelola    9033218196
# 1   63d02adb-4232-47e0-a9d2-26dea1c419b4  Chimamanda    Dahiru    9138637940
# 2   2bdbec2c-f385-45a4-a179-a968107210ab       Ekene   Oyedepo    9011615594
# 3   a8685507-4209-4d0c-94a2-908836bbaf8c     Oladipo       Obi    9149593103
# 4   2d2d0fe8-e662-452e-a2dc-1e59ab3cec87   Morakinyo  Offodile    7052553419
# 5   597b1a60-779b-4583-b32a-b21704dae686       Lawan  Offodile    9135030564
# 6   6fd88cc5-96b6-4f76-ba94-0a5a2f921b6e    Patience      Bala    7024238849
# 7   cb585949-9c0c-439b-96ef-5650b835f639    Olatunji  Galadima    8001226916
# 8   2a723471-3ac9-451e-9621-f6412009ee98  Adetokunbo   YarAdua    9145146270
# 9   66d51201-994e-4bc1-be8b-39ee857d54b5      Muyiwa    Okonjo    9193252880
# 10  eb0337f4-c731-400a-85df-3a75f965fdc1       Ngozi  Nwabueze    8103911718
# ...

# %%
dataset.groupby('income_level').count()
# Out:
#               user_id  first_name  last_name  phone_number   email   state  \
# income_level
# 100k-250k      352597      352597     352597        352597  352597  352597
# 250k-500k      353906      353906     353906        353906  353906  353906
# 50k-100k       352822      352822     352822        352822  352822  352822
# Above 500k     352339      352339     352339        352339  352339  352339
# Below 50k      354228      354228     354228        354228  354228  354228
#
#               region  registration_date     age  gender  occupation
# income_level
# 100k-250k     352597             352597  352597  352597      352597
# 250k-500k     353906             353906  353906  353906      353906
# 50k-100k      352822             352822  352822  352822      352822
# Above 500k    352339             352339  352339  352339      352339
# Below 50k     354228             354228  354228  354228      354228

# %%
dataset.user_id.count()
# Out:
# 1765892

# %%
dataset.registration_date.min()
# Out:
# '2022-05-03'

# %%
dataset.groupby('age').count()
# Out:
#      user_id  first_name  last_name  phone_number  email  state  region  \
# age
# 18     33251       33251      33251         33251  33251  33251   33251
# 19     33430       33430      33430         33430  33430  33430   33430
# 20     33440       33440      33440         33440  33440  33440   33440
# 21     33116       33116      33116         33116  33116  33116   33116
# 22     33360       33360      33360         33360  33360  33360   33360
# 23     33277       33277      33277         33277  33277  33277   33277
# 24     33373       33373      33373         33373  33373  33373   33373
# 25     33530       33530      33530         33530  33530  33530   33530
# 26     33445       33445      33445         33445  33445  33445   33445
# 27     33235       33235      33235         33235  33235  33235   33235
# 28     33429       33429      33429         33429  33429  33429   33429
# 29     33331       33331      33331         33331  33331  33331   33331
# ...

# %%
dataset[(dataset['first_name'] == 'Destiny') & (dataset['last_name'] == 'Johnson')]
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, phone_number, email, state, region, registration_date, age, gender, occupation, income_level]
# Index: []

# %%
dataset.groupby('state').count()
# Out:
#              user_id  first_name  last_name  phone_number  email  region  \
# state
# Abia           47837       47837      47837         47837  47837   47837
# Adamawa        47462       47462      47462         47462  47462   47462
# Akwa Ibom      47834       47834      47834         47834  47834   47834
# Anambra        47547       47547      47547         47547  47547   47547
# Bauchi         47823       47823      47823         47823  47823   47823
# Bayelsa        47804       47804      47804         47804  47804   47804
# Benue          47888       47888      47888         47888  47888   47888
# Borno          47850       47850      47850         47850  47850   47850
# Cross River    47738       47738      47738         47738  47738   47738
# Delta          47593       47593      47593         47593  47593   47593
# Ebonyi         47811       47811      47811         47811  47811   47811
# Edo            47736       47736      47736         47736  47736   47736
# ...
